# %% [markdown]
# <a href="https://colab.research.google.com/github/SunX97/reponew/blob/main/matplotlibpythonassesment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Activity 1
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [2,5,4,8,10]

plt.plot(x,y)
plt.title("Line plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
from sklearn.datasets import load_iris
iris = load_iris(as_frame = True)
df = iris.frame
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]

# %%
#Activity 2
plt.scatter(df["sepal length (cm)"],df["petal length (cm)"])
plt.xlabel("sepal length (cm)")
plt.ylabel("sepal width (cm)")
plt.show()

# %%
#Activity 3
plt.hist(df["petal width (cm)"])
plt.title("Distribution")
plt.show()

# %%
#Activity 4
species = ['Setosa','Versicolor','Virginica']
count = df['target'].value_counts()
plt.bar(species,count)
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()

# %%
plot july month temperature of two cities( of your choice) on the same graph should be real datas graph should be line plot.
