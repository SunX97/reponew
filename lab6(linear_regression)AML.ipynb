# %% [markdown]
# <a href="https://colab.research.google.com/github/SunX97/reponew/blob/main/lab6(linear_regression)AML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
#uploading Datasets

df =pd.read_csv('/content/score_updated.csv')
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.shape
# Out:
# (96, 2)

# %%
# Define input data
x = df[["Hours"]]

# Define target data
y = df["Scores"]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)


# Instantiate the LinearRegression model
decision_model = LinearRegression()

decision_model.fit(x_train, y_train)

decision_pred = decision_model.predict(x_test)

# %%
# Predict using the Decision Tree model
decision_pred = decision_model.predict(x_test)

print(decision_pred)
# Out:
# [28.01321679 50.63517747 31.94747083 38.83241538 82.10920972 87.02702726
#  76.20782868 68.33932061 27.02965329 78.17495569 55.55299501 18.17758172
#  62.43793957 36.86528836 90.96128129 95.87909883 46.70092344 39.81597889
#  37.84885187 51.61874098]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Evaluation metrics
mse = mean_squared_error(y_test, decision_pred)
mae = mean_absolute_error(y_test, decision_pred)
rmse = mean_squared_error(y_test, decision_pred) ** 0.5
r2 = r2_score(y_test, decision_pred)

print("MSE :", mse)
print("MAE :", mae)
print("RMSE:", rmse)
print("R2  :", r2)
# Out:
# MSE : 17.007444250866516
# MAE : 3.3702236454952397
# RMSE: 4.124008274830024
# R2  : 0.9708871356050831

# %%
import matplotlib.pyplot as plt
import numpy as np

# Flatten x_test.values to ensure sort_index is 1D
x_test_flat = x_test.values.flatten()
sort_index = np.argsort(x_test_flat)

plt.figure(figsize=(8, 5))

# Plot scatter of actual values, using flattened x_test
plt.scatter(x_test_flat, y_test, color="blue", label="Actual")

# Plot the regression line, using 1D sorted arrays
plt.plot(
    x_test_flat[sort_index],
    decision_pred[sort_index],
    color="red",
    linewidth=2,
    label="Regression Line"
)

plt.title("Linear Regression", fontsize=14, fontweight="bold")
plt.xlabel("Study hours")
plt.ylabel("Marks")

plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
# Take input from user
input_value = float(input("Enter the Hours Studied: "))

# Predict marks
prediction = decision_model.predict([[input_value]])

print("Predicted marks:", round(prediction[0], 0), "Marks")
# Out:
# Enter the Hours Studied: 2
# Predicted marks: 22.0 Marks
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
